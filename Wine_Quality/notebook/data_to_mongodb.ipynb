# %%
import pandas as pd

# %%
data=pd.read_csv("D:\DEEPLEARNING COURSE\Projects End to End\Project 2\Data\WineQT.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df=data

# %%
data=df.to_dict(orient="records")
data[0]
# Out:
# {'fixed acidity': 7.4,
#  'volatile acidity': 0.7,
#  'citric acid': 0.0,
#  'residual sugar': 1.9,
#  'chlorides': 0.076,
#  'free sulfur dioxide': 11.0,
#  'total sulfur dioxide': 34.0,
#  'density': 0.9978,
#  'pH': 3.51,
#  'sulphates': 0.56,
#  'alcohol': 9.4,
#  'quality': 5,
#  'Id': 0}

# %%
Db_Name="wine_DB"
Collection_Name="wine_Collection"
Connection_URL=" your url here "

# %%
print("ok")
# Out:
# ok

# %%
import pymongo
client=pymongo.MongoClient(Connection_URL)
db=client[Db_Name]
collection=db[Collection_Name]

# %%
re=collection.insert_many(data)

# %%
##### I basically grabbing everything from MongoDB Collection And chucking it into a DataFrame so we can see it nicely -- 
##### Like if you have mongoDB low title this is how you canread the data when they give you user and db/collection name then you can access it like below
cabdi=pd.DataFrame(list(collection.find()))
cabdi.head()
# Out:
#                         _id  fixed acidity  volatile acidity  citric acid  \
# 0  6910934b2dc1669cf274a521            7.4              0.70         0.00
# 1  6910934b2dc1669cf274a522            7.8              0.88         0.00
# 2  6910934b2dc1669cf274a523            7.8              0.76         0.04
# 3  6910934b2dc1669cf274a524           11.2              0.28         0.56
# 4  6910934b2dc1669cf274a525            7.4              0.70         0.00
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             1.9      0.076                 11.0                  34.0
# 1             2.6      0.098                 25.0                  67.0
# 2             2.3      0.092                 15.0                  54.0
# 3             1.9      0.075                 17.0                  60.0
# 4             1.9      0.076                 11.0                  34.0
#
#    density    pH  sulphates  alcohol  quality  Id
# ...
